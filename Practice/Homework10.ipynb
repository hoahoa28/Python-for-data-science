# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Bài toán: classification
#
# Input: ảnh người
#
# Output: ảnh hoạt hình tương ứng

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.   Bài toán: Classification
# 2.   Input: Chiều dài của cánh hoa và lá
# 3.   Output: Loại hoa Iris:
# -- Iris Setosa
#
#
#
# -- Iris Versicolour
#
# -- Iris Virginica

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.   Bài toán: Classification
# 2.   Input: Hình ảnh biểu cảm khuôn mặt con người
# 3.   Output: Biểu tượng cảm xúc tương ứng

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Bài toán: regression
# 2. Input: tình trạng hôn nhân, giáo dục, số lượng người phụ thuộc và việc làm
# 3. Output: tiền vay nợ

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Bài toán: Regression
# 2. Input:
#
# CRIM - tỷ lệ tội phạm bình quân đầu người theo thị trấn
#
# ZN - tỷ lệ đất ở được quy hoạch cho các lô trên 25.000 bộ vuông.
#
# INDUS - tỷ lệ mẫu đất kinh doanh phi bán lẻ trên mỗi thị trấn.
#
# CHAS - Biến giả sông Charles (1 nếu đường giáp sông; 0 nếu không)
#
# NOX - nồng độ oxit nitric (phần trên 10 triệu)
#
# RM - số phòng trung bình trên mỗi căn nhà
#
# TUỔI - tỷ lệ các đơn vị sở hữu chủ sở hữu được xây dựng trước năm 1940
#
# DIS - khoảng cách có trọng số đến năm trung tâm việc làm ở Boston
#
# RAD - chỉ số khả năng tiếp cận đường cao tốc xuyên tâm
#
# THUẾ - thuế suất bất động sản toàn giá trị trên 10.000 đô la
#
# PTRATIO - tỷ lệ học sinh-giáo viên theo thị trấn
#
# B - 1000(Bk - 0,63)^2 trong đó Bk là tỷ lệ người da đen theo thị trấn
#
# LSTAT - % tình trạng thấp hơn của dân số
#
# MEDV - Giá trị trung bình của những ngôi nhà do chủ sở hữu sử dụng tính bằng $1000
# 3. Output: Giá nhà

# %% [markdown]
# 6. MNIST Digit Classification Machine Learning Project
#
# Bài toán: Classification
#
# Input: hình ảnh số viết tay
#
# output: số ứng với hình ảnh đó

# %% [markdown]
# 7. Stock Price Prediction using Machine Learning
#
# Bài toán: Regression
#
# Input: Giá cổ phiếu của những năm trước
#
# Output: Giá cổ phiếu tương lai

# %% [markdown]
# 8. Titanic Survival Project
#
# bài toán: clustering
#
# input: dữ liệu thực về những người sống sót và những người đã chết trong con tàu Titanic.
#
# output: tình trạng sống / chết của các nạn nhân

# %% [markdown]
# 9. Wine Quality Test Project
#
# bài toán: classification / regression
#
# input: thông tin các chất hóa học trong rượu
#
# output: chất lượng rượu

# %% [markdown]
# 10. Fake News Detection Project
#
# bài toán: classification
#
# input: các tin tức thật và giả
#
# output: tin tức đó là thật hay giả

# %% [markdown]
# 11. Music Genre Classification Machine Learning Project
#
# bài toán: classification
#
# input: các file audio chứa các bản nhạc
#
# output: thể loại âm nhạc

# %% [markdown]
# 12. Bitcoin Price Predictor Project
#
# bài toán: regression
#
# input: thông tin về giá trong quá khứ
#
# output: thông tin trong tương lai

# %% [markdown]
# 13. Uber Data Analysis Project
#
# bài toán: visuallize các thông tin về các chuyến xe của Uber ở NewYork
#
# input: các thông tin về chuyến xe
#
# output: biểu đồ

# %% [markdown]
# 14. Personality Prediction Project
#
# bài toán: clustering
#
# input: thông tin về loại tính cách và bài post của họ
#
# output: loại tính cách

# %% [markdown]
# 15. Handwritten Character Recognition
#
# bài toán: classification
#
# input: hình ảnh chữ viết tay
#
# output: chữ tương ứng với hình ảnh đó

# %% [markdown]
# 16. Xbox Game Prediction Project
#
# bài toán: clusering
#
# input: kết quả tìm kiếm của các khách hàng
#
# output: game mà từng người dùng hứng thú

# %% [markdown]
# 17. Xbox Game Prediction Project
#
# bài toán:regression
#
# input: sử dụng giao dịch và nhãn của chúng là gian lận hoặc không gian lận
#
# ouput: phát hiện giao dịch mới có phải gian lận hay không

# %% [markdown]
# 18. Sign Language Recognition with Machine Learning
#
# bài toán: classification
#
# input: hình ảnh ngôn ngữ ký hiệu
#
# output: ký tự tương ứng

# %% [markdown]
# 20. Customer Segmentation using Machine Learning
#
# bài toán: clustering
#
# input: khách hàng dựa trên lịch sử mua hàng, giới tính, độ tuổi, sở thích,..
#
# output: phân khúc khách hàng

# %% [markdown]
# 21. Sentiment Analysis using Machine Learning
#
# bài toán: classification
#
# input: các emoji mà khách hàng dùng để đánh giá
#
# output: thái độ của khách hàng tích cực, tiêu cực hay trung lập

# %% [markdown]
# 23. Speech Emotion Recognition Machine Learning Project
#
# bài toán: classification
#
# input: giọng nói
#
# output: cảm xúc

# %% [markdown]
# 25. Online Grocery Recommendation using Collaborative Filtering
#
# bài toán: clustering
#
# input: phản ứng hành vi lựa chọn hàng hóa của các khách hàng
#
# output: gợi ý các sản phẩm phù hợp với các khách hàng khác tương tự

# %% [markdown]
# 26. Movie Recommendation System using Machine Learning
#
# bài toán: clustering
#
# input: hành vi xem phim của người dùng
#
# output: gợi ý phim

# %% [markdown]
# 27. Automatic License Number Plate Recognition System
#
# bài toán: classification
#
# input: biển số xe
#
# output: tên biển số xe và số giấy phép in trên biển số xe

# %% [markdown]
# 28. Image Segmentation with Machine Learning
#
# bài toán: classification
#
# input: hình ảnh
#
# output: vị trí các đối tượng trong ảnh
